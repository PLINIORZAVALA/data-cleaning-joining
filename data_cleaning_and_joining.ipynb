# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
import os

# Configuration
base_path = 'lista_certificados'

# 1. Identify a sample file
files = [f for f in os.listdir(base_path) if f.endswith('.xlsx')]
if files:
    sample_file = files[0]
    sample_file_path = os.path.join(base_path, sample_file)

    print(f"Sample file selected: {sample_file}")

    # 2. Read the file sheets
    xls = pd.ExcelFile(sample_file_path)
    sheet_names = xls.sheet_names
    print(f"Sheets found: {sheet_names}")

    # 3. Read each sheet individually
    # Assuming there are two sheets as per description
    if len(sheet_names) >= 2:
        df_hoja1 = pd.read_excel(sample_file_path, sheet_name=0)
        df_hoja2 = pd.read_excel(sample_file_path, sheet_name=1)

        print("\n--- Sheet 1 Preview ---")
        display(df_hoja1.head())
        print(f"Dimensions: {df_hoja1.shape}")

        print("\n--- Sheet 2 Preview ---")
        display(df_hoja2.head())
        print(f"Dimensions: {df_hoja2.shape}")
    else:
        print("The file does not have at least 2 sheets.")
else:
    print("No .xlsx files found in the folder.")
# Out:
# Sample file selected: 29. INFORME ITEC GENERAL junio 2 - COLEGIO DE PROFESORES.xlsx
# Sheets found: ['FORMATO DE CERTIFICACIÓN A1', 'Hoja1']
#
# --- Sheet 1 Preview ---
#   REGISTRO DE CERTIFICADOS\nDESARROLLADO POR EL COLEGIO DE PROFESORES DEL PERU E ITEC PERÚ\n06 DE JUNIO AL 17 DE JUNIO DE 2022   \
# 0                                                 N°
# 1                                                  1
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#      Unnamed: 1         Unnamed: 2 Unnamed: 3  \
# 0  COORDINADORA             CÓDIGO        DNI
# 1         FELIX  CPPe-ITECV22-0390   25732863
# 2          ROSA  CPPe-ITECV22-0391   75023950
# 3         LUCIA  CPPe-ITECV22-0392   73828956
# 4         LUCIA  CPPe-ITECV22-0393   46842993
#
#                              Unnamed: 4  \
# 0                   APELLIDOS Y NOMBRES
# 1      VALENZUELA ANTÓN, CARLOS ENRIQUE
# 2     VILCARIMA TORRES, YAJAHYRA ISABEL
# 3       CAYCHO MORENO, MARÍA DEL CARMEN
# 4  CHUMBE MUÑOZ, LUISA VANESSA DE JESÚS
#
#                                     Unnamed: 5 Unnamed: 6  Unnamed: 7  \
# 0                                        CURSO       NOTA    NOTA TXT
# 1         DISEÑO DE PÁGINAS WEB - NIVEL BÁSICO         17  DIECISIETE
# 2      DISEÑO DIGITAL CON CANVA - NIVEL BÁSICO         19  DIECINUEVE
# 3  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO         15      QUINCE
# 4  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO         19  DIECINUEVE
#
#                                Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0                                 PERIODO      HORAS  N° CELULAR
# 1   31 - mayo - 2022 al 11 - junio - 2022  120 horas   992667425
# 2   23 - mayo - 2022 al 03 - junio - 2022  120 horas   932350437
# 3  07 - junio - 2022 al 18 - junio - 2022  120 horas   992118759
# 4  07 - junio - 2022 al 18 - junio - 2022  120 horas   987762080
#
#                     Unnamed: 11 Unnamed: 12
# 0                         EMAIL      CIUDAD
# 1            cvalen22@gmail.com        LIMA
# 2           Yahavilto@gmail.com         ICA
# 3  mariamoreno205757@gmail.com         LIMA
# 4          vanexitach@gmail.com        LIMA
# Dimensions: (46, 13)
#
# --- Sheet 2 Preview ---
#                                           Unnamed: 0        Unnamed: 1
# 0                     COLEGIO DE PROFESORES DEL PERU               NaN
# 1                                             CURSO   Cuenta de CÓDIGO
# 2  IMPLEMENTACIÓN Y ADMINISTRACIÓN DE AULAS DE IN...                15
# 3        DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO                 8
# 4    DISEÑO GRÁFICO CON CORELDRAW - NIVEL INTERMEDIO                 7
# Dimensions: (15, 2)

# %%
import os
import openpyxl

# Configuration
base_path = 'lista_certificados'

print("Starting the process of deleting 'Hoja1' from all Excel files...")

# Iterate through all files in the directory
files = [f for f in os.listdir(base_path) if f.endswith('.xlsx')]

processed_count = 0
errors = []

for filename in files:
    file_path = os.path.join(base_path, filename)
    
    try:
        # Load the workbook
        wb = openpyxl.load_workbook(file_path)
        
        # Check if 'Hoja1' exists
        if 'Hoja1' in wb.sheetnames:
            # Get the sheet and remove it
            std = wb['Hoja1']
            wb.remove(std)
            
            # Save the file
            wb.save(file_path)
            print(f"Processed: {filename} (Removed 'Hoja1')")
            processed_count += 1
        else:
            print(f"Skipped: {filename} ('Hoja1' not found)")
            
    except Exception as e:
        print(f"Error processing {filename}: {e}")
        errors.append(filename)

print(f"\nProcess completed.")
print(f"Total files processed: {processed_count}")
print(f"Total errors: {len(errors)}")
# Out:
# Starting the process of deleting 'Hoja1' from all Excel files...
# Processed: 29. INFORME ITEC GENERAL junio 2 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 5. INFORME ITEC GENERAL  FEBRERO 2.xlsx (Removed 'Hoja1')
# Processed: 57. INFORME ITEC GENERAL setiembre 4 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 47. INFORME CORLAD GENERAL agosto 3 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 2. INFORME GENERAL 10 AL 21 ENERO 22.xlsx (Removed 'Hoja1')
# Processed: 18. INFORME ITEC GENERAL mayo 3 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 45. INFORME CORLAD GENERAL agosto 2 - CORLAD (1).xlsx (Removed 'Hoja1')
# Processed: 6. INFORME ITEC GENERAL FEBRERO 3.xlsx (Removed 'Hoja1')
# Processed: 41. INFORME CORLAD GENERAL julio 4 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 34. INFORME ITEC GENERAL julio 1 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 48. INFORME DOCENTES GENERAL agosto 3 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 40. INFORME ITEC GENERAL julio 4 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 11. INFORME ITEC GENERAL Marzo3.xlsx (Removed 'Hoja1')
# Processed: 26. INFORME ITEC GENERAL junio 1 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 7. INFORME ITEC GENERAL FEBRERO 4.xlsx (Removed 'Hoja1')
# Processed: 55. INFORME ITEC GENERAL setiembre 3 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 4. INFORME ITEC GENERAL FEBRERO 1.xlsx (Removed 'Hoja1')
# Processed: 25. DREA -INFORME ITEC GENERAL (MARZO).xlsx (Removed 'Hoja1')
# Skipped: 1. INFORME GENERAL 04 AL 15 ENERO 22.xlsx ('Hoja1' not found)
# Processed: 9. INFORME ITEC GENERAL Marzo1.xlsx (Removed 'Hoja1')
# Processed: 49. INFORME corlad GENERAL agosto 4 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 10. INFORME ITEC GENERAL Marzo2.xlsx (Removed 'Hoja1')
# Processed: 56. INFORME profesores GENERAL setiembre 3 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 21. INFORME ITEC GENERAL ABRIL.xlsx (Removed 'Hoja1')
# Processed: 60. INFORME ITEC GENERAL setiembre 5 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 54. INFORME profesores GENERAL setiembre 2 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 33. INFORME profesores GENERAL junio 4 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 59. INFORME COLRAD setiembre 5 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 20. INFORME ITEC GENERAL mayo 4 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 43. INFORME ITEC GENERAL agosto 1 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 17. INFORME ITEC GENERAL mayo 3- CORLAD.xlsx (Removed 'Hoja1')
# Processed: 15. INFORME ITEC GENERAL mayo 2- CORLAD.xlsx (Removed 'Hoja1')
# Processed: 3. INFORME ITEC GENERAL 18 AL 29 ENERO 22.xlsx (Removed 'Hoja1')
# Processed: 27. INFORME ITEC GENERAL junio 1 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 51. INFORME CORLAD OK GENERAL setiembre 1 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 50. INFORME profesores GENERAL agosto 4 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 14. INFORME ITEC GENERAL mayo 1 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 35. INFORME ITEC GENERAL julio 1 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 44. INFORME ITEC GENERAL agosto 1 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 22. INFORME ITEC GENERAL Abril 2.xlsx (Removed 'Hoja1')
# Processed: 12. INFORME ITEC GENERAL Marzo4.xlsx (Removed 'Hoja1')
# Processed: 53. INFORME ITEC GENERAL setiembre 2 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 42. INFORME ITEC GENERAL julio 5 - CORLAD1.xlsx (Removed 'Hoja1')
# Processed: 8. INFORME ITEC GENERAL FEBRERO 5.xlsx (Removed 'Hoja1')
# Processed: 38. INFORME ITEC GENERAL julio 3 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 28. INFORME ITEC GENERAL junio 2 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 36. INFORME ITEC GENERAL julio 2 - CORLAD OK.xlsx (Removed 'Hoja1')
# Processed: 19. INFORME ITEC GENERAL mayo 4 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 41. INFORME ITEC GENERAL julio 5 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 58. INFORME ITEC GENERAL setiembre 4 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 16. INFORME ITEC GENERAL mayo 2 - COLEGIO DE PROFESORES - copia.xlsx (Removed 'Hoja1')
# Processed: 23. INFORME ITEC GENERAL Abril 3 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 46. INFORME PROFESORES GENERAL agosto 2 - COLEGIO DE PROFESORES (1).xlsx (Removed 'Hoja1')
# Processed: 32. INFORME CORLAD GENERAL junio 4 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 31. INFORME ITEC GENERAL junio 3 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 37. INFORME ITEC GENERAL julio 2 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 13. INFORME ITEC GENERAL mayo 1- CORLAD.xlsx (Removed 'Hoja1')
# Processed: 30. INFORME ITEC GENERAL junio 3 - CORLAD.xlsx (Removed 'Hoja1')
# Processed: 52. INFORME profesores GENERAL setiembre 1 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
# Processed: 24. INFORME ITEC GENERAL Abril 3 - COLEGIO DE P.xlsx (Removed 'Hoja1')
# Processed: 39. INFORME ITEC GENERAL julio 3 - COLEGIO DE PROFESORES.xlsx (Removed 'Hoja1')
#
# Process completed.
# Total files processed: 60
# Total errors: 0

# %%
# Validation: Check that all files have exactly 1 sheet
files = [f for f in os.listdir(base_path) if f.endswith('.xlsx')]
issues = []

print("Validating sheet counts...")
for f in files:
    wb = openpyxl.load_workbook(os.path.join(base_path, f), read_only=True)
    if len(wb.sheetnames) != 1:
        issues.append(f"{f}: {len(wb.sheetnames)} sheets ({wb.sheetnames})")
    wb.close()

if issues:
    print(f"Found {len(issues)} files with unexpected sheet counts:")
    for i in issues:
        print(i)
else:
    print(f"SUCCESS: All {len(files)} files have exactly 1 sheet.")
# Out:
# Validating sheet counts...
# SUCCESS: All 61 files have exactly 1 sheet.

# %%
import openpyxl

print("Removing the first row and first column from all files...")

processed_count = 0
files = [f for f in os.listdir(base_path) if f.endswith('.xlsx')]

for filename in files:
    file_path = os.path.join(base_path, filename)
    try:
        wb = openpyxl.load_workbook(file_path)
        ws = wb.active
        
        # 1. Delete the first row (Header with title)
        ws.delete_rows(1)
        
        # 2. Delete the first column (Index/Numbering)
        ws.delete_cols(1)
        
        wb.save(file_path)
        processed_count += 1
        
    except Exception as e:
        print(f"Error processing {filename}: {e}")

print(f"Completed. Processed {processed_count} files.")

# Verify with a sample
if files:
    sample = files[0]
    print(f"\nVerifying sample: {sample}")
    df_check = pd.read_excel(os.path.join(base_path, sample))
    display(df_check.head())
# Out:
# Removing the first row and first column from all files...
# Completed. Processed 61 files.
#
# Verifying sample: 29. INFORME ITEC GENERAL junio 2 - COLEGIO DE PROFESORES.xlsx
#   COORDINADORA             CÓDIGO       DNI  \
# 0        FELIX  CPPe-ITECV22-0390  25732863
# 1         ROSA  CPPe-ITECV22-0391  75023950
# 2        LUCIA  CPPe-ITECV22-0392  73828956
# 3        LUCIA  CPPe-ITECV22-0393  46842993
# 4        LUCIA  CPPe-ITECV22-0394  15432849
#
#                     APELLIDOS Y NOMBRES  \
# 0      VALENZUELA ANTÓN, CARLOS ENRIQUE
# 1     VILCARIMA TORRES, YAJAHYRA ISABEL
# 2       CAYCHO MORENO, MARÍA DEL CARMEN
# 3  CHUMBE MUÑOZ, LUISA VANESSA DE JESÚS
# 4       DE LA CRUZ AGUADO, ALEX ALFREDO
#
#                                          CURSO  NOTA    NOTA TXT  \
# 0         DISEÑO DE PÁGINAS WEB - NIVEL BÁSICO    17  DIECISIETE
# 1      DISEÑO DIGITAL CON CANVA - NIVEL BÁSICO    19  DIECINUEVE
# 2  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO    15      QUINCE
# 3  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO    19  DIECINUEVE
# 4  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO    19  DIECINUEVE
#
#                                   PERIODO      HORAS N° CELULAR  \
# 0   31 - mayo - 2022 al 11 - junio - 2022  120 horas  992667425
# 1   23 - mayo - 2022 al 03 - junio - 2022  120 horas  932350437
# 2  07 - junio - 2022 al 18 - junio - 2022  120 horas  992118759
# 3  07 - junio - 2022 al 18 - junio - 2022  120 horas  987762080
# 4  07 - junio - 2022 al 18 - junio - 2022  120 horas  995443327
#
#                           EMAIL CIUDAD
# 0            cvalen22@gmail.com   LIMA
# 1           Yahavilto@gmail.com    ICA
# 2  mariamoreno205757@gmail.com    LIMA
# 3          vanexitach@gmail.com   LIMA
# 4          Profalex17@gmail.com   LIMA

# %%
# Define the columns to remove
cols_to_remove = ['CÓDIGO', 'DNI', 'APELLIDOS Y NOMBRES', 'N° CELULAR', 'EMAIL']

print(f"Removing columns: {cols_to_remove}")

processed_count = 0
files = [f for f in os.listdir(base_path) if f.endswith('.xlsx')]

for filename in files:
    file_path = os.path.join(base_path, filename)
    try:
        # Read the file
        df = pd.read_excel(file_path)
        
        # Identify which columns from the list are present in the file
        # We strip whitespace just in case there are hidden spaces
        columns_map = {c.strip(): c for c in df.columns}
        
        cols_to_drop_actual = []
        for target in cols_to_remove:
            # Check exact match or stripped match
            if target in df.columns:
                cols_to_drop_actual.append(target)
            elif target in columns_map:
                cols_to_drop_actual.append(columns_map[target])
        
        if cols_to_drop_actual:
            # Drop the columns
            df = df.drop(columns=cols_to_drop_actual)
            
            # Save back to Excel without the index
            df.to_excel(file_path, index=False)
            processed_count += 1
            print(f"Processed: {filename} (Dropped {len(cols_to_drop_actual)} columns)")
        else:
            print(f"Skipped: {filename} (Target columns not found)")
            
    except Exception as e:
        print(f"Error processing {filename}: {e}")

print(f"\nProcess completed. Files updated: {processed_count}")

# Verify with a sample
if files:
    print("\n--- Verification Sample ---")
    sample_df = pd.read_excel(os.path.join(base_path, files[0]))
    display(sample_df.head())
    print("Columns remaining:", sample_df.columns.tolist())
# Out:
# Removing columns: ['CÓDIGO', 'DNI', 'APELLIDOS Y NOMBRES', 'N° CELULAR', 'EMAIL']
# Processed: 29. INFORME ITEC GENERAL junio 2 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 5. INFORME ITEC GENERAL  FEBRERO 2.xlsx (Dropped 5 columns)
# Processed: 57. INFORME ITEC GENERAL setiembre 4 - CORLAD.xlsx (Dropped 5 columns)
# Processed: 47. INFORME CORLAD GENERAL agosto 3 - CORLAD.xlsx (Dropped 3 columns)
# Processed: 2. INFORME GENERAL 10 AL 21 ENERO 22.xlsx (Dropped 5 columns)
# Processed: 18. INFORME ITEC GENERAL mayo 3 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 45. INFORME CORLAD GENERAL agosto 2 - CORLAD (1).xlsx (Dropped 3 columns)
# Processed: 6. INFORME ITEC GENERAL FEBRERO 3.xlsx (Dropped 5 columns)
# Processed: 41. INFORME CORLAD GENERAL julio 4 - CORLAD.xlsx (Dropped 3 columns)
# Processed: 34. INFORME ITEC GENERAL julio 1 - CORLAD.xlsx (Dropped 5 columns)
# Processed: 48. INFORME DOCENTES GENERAL agosto 3 - COLEGIO DE PROFESORES.xlsx (Dropped 3 columns)
# Processed: 40. INFORME ITEC GENERAL julio 4 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 11. INFORME ITEC GENERAL Marzo3.xlsx (Dropped 5 columns)
# Processed: 26. INFORME ITEC GENERAL junio 1 - CORLAD.xlsx (Dropped 5 columns)
# Processed: 7. INFORME ITEC GENERAL FEBRERO 4.xlsx (Dropped 5 columns)
# Processed: 55. INFORME ITEC GENERAL setiembre 3 - CORLAD.xlsx (Dropped 5 columns)
# Processed: 4. INFORME ITEC GENERAL FEBRERO 1.xlsx (Dropped 5 columns)
# Processed: 25. DREA -INFORME ITEC GENERAL (MARZO).xlsx (Dropped 5 columns)
# Processed: 1. INFORME GENERAL 04 AL 15 ENERO 22.xlsx (Dropped 5 columns)
# Processed: 9. INFORME ITEC GENERAL Marzo1.xlsx (Dropped 5 columns)
# Processed: 49. INFORME corlad GENERAL agosto 4 - CORLAD.xlsx (Dropped 3 columns)
# Processed: 10. INFORME ITEC GENERAL Marzo2.xlsx (Dropped 5 columns)
# Processed: 56. INFORME profesores GENERAL setiembre 3 - COLEGIO DE PROFESORES.xlsx (Dropped 3 columns)
# Processed: 21. INFORME ITEC GENERAL ABRIL.xlsx (Dropped 5 columns)
# Processed: 60. INFORME ITEC GENERAL setiembre 5 - COLEGIO DE PROFESORES.xlsx (Dropped 3 columns)
# Processed: 54. INFORME profesores GENERAL setiembre 2 - COLEGIO DE PROFESORES.xlsx (Dropped 3 columns)
# Processed: 33. INFORME profesores GENERAL junio 4 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 59. INFORME COLRAD setiembre 5 - CORLAD.xlsx (Dropped 3 columns)
# Processed: 20. INFORME ITEC GENERAL mayo 4 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 43. INFORME ITEC GENERAL agosto 1 - CORLAD.xlsx (Dropped 5 columns)
# Processed: 17. INFORME ITEC GENERAL mayo 3- CORLAD.xlsx (Dropped 5 columns)
# Processed: 15. INFORME ITEC GENERAL mayo 2- CORLAD.xlsx (Dropped 5 columns)
# Processed: 3. INFORME ITEC GENERAL 18 AL 29 ENERO 22.xlsx (Dropped 5 columns)
# Processed: 27. INFORME ITEC GENERAL junio 1 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 51. INFORME CORLAD OK GENERAL setiembre 1 - CORLAD.xlsx (Dropped 3 columns)
# Processed: 50. INFORME profesores GENERAL agosto 4 - COLEGIO DE PROFESORES.xlsx (Dropped 3 columns)
# Processed: 14. INFORME ITEC GENERAL mayo 1 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 35. INFORME ITEC GENERAL julio 1 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 44. INFORME ITEC GENERAL agosto 1 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 22. INFORME ITEC GENERAL Abril 2.xlsx (Dropped 5 columns)
# Processed: 12. INFORME ITEC GENERAL Marzo4.xlsx (Dropped 5 columns)
# Processed: 53. INFORME ITEC GENERAL setiembre 2 - CORLAD.xlsx (Dropped 3 columns)
# Processed: 42. INFORME ITEC GENERAL julio 5 - CORLAD1.xlsx (Dropped 5 columns)
# Processed: 8. INFORME ITEC GENERAL FEBRERO 5.xlsx (Dropped 5 columns)
# Processed: 38. INFORME ITEC GENERAL julio 3 - CORLAD.xlsx (Dropped 5 columns)
# Processed: 28. INFORME ITEC GENERAL junio 2 - CORLAD.xlsx (Dropped 5 columns)
# Processed: 36. INFORME ITEC GENERAL julio 2 - CORLAD OK.xlsx (Dropped 5 columns)
# Processed: 19. INFORME ITEC GENERAL mayo 4 - CORLAD.xlsx (Dropped 5 columns)
# Processed: 41. INFORME ITEC GENERAL julio 5 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 58. INFORME ITEC GENERAL setiembre 4 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 16. INFORME ITEC GENERAL mayo 2 - COLEGIO DE PROFESORES - copia.xlsx (Dropped 5 columns)
# Processed: 23. INFORME ITEC GENERAL Abril 3 - CORLAD.xlsx (Dropped 5 columns)
# Processed: 46. INFORME PROFESORES GENERAL agosto 2 - COLEGIO DE PROFESORES (1).xlsx (Dropped 3 columns)
# Processed: 32. INFORME CORLAD GENERAL junio 4 - CORLAD.xlsx (Dropped 3 columns)
# Processed: 31. INFORME ITEC GENERAL junio 3 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 37. INFORME ITEC GENERAL julio 2 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
# Processed: 13. INFORME ITEC GENERAL mayo 1- CORLAD.xlsx (Dropped 5 columns)
# Processed: 30. INFORME ITEC GENERAL junio 3 - CORLAD.xlsx (Dropped 5 columns)
# Processed: 52. INFORME profesores GENERAL setiembre 1 - COLEGIO DE PROFESORES.xlsx (Dropped 3 columns)
# Processed: 24. INFORME ITEC GENERAL Abril 3 - COLEGIO DE P.xlsx (Dropped 5 columns)
# Processed: 39. INFORME ITEC GENERAL julio 3 - COLEGIO DE PROFESORES.xlsx (Dropped 5 columns)
#
# Process completed. Files updated: 61
#
# --- Verification Sample ---
#   COORDINADORA                                        CURSO  NOTA    NOTA TXT  \
# 0        FELIX         DISEÑO DE PÁGINAS WEB - NIVEL BÁSICO    17  DIECISIETE
# 1         ROSA      DISEÑO DIGITAL CON CANVA - NIVEL BÁSICO    19  DIECINUEVE
# 2        LUCIA  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO    15      QUINCE
# 3        LUCIA  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO    19  DIECINUEVE
# 4        LUCIA  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO    19  DIECINUEVE
#
#                                   PERIODO      HORAS CIUDAD
# 0   31 - mayo - 2022 al 11 - junio - 2022  120 horas   LIMA
# 1   23 - mayo - 2022 al 03 - junio - 2022  120 horas    ICA
# 2  07 - junio - 2022 al 18 - junio - 2022  120 horas   LIMA
# 3  07 - junio - 2022 al 18 - junio - 2022  120 horas   LIMA
# 4  07 - junio - 2022 al 18 - junio - 2022  120 horas   LIMA
# Columns remaining: ['COORDINADORA', 'CURSO', 'NOTA', 'NOTA TXT', 'PERIODO', 'HORAS', 'CIUDAD']

# %%
# Create the output directory if it doesn't exist
output_folder = os.path.join(base_path, 'anion_data')
os.makedirs(output_folder, exist_ok=True)

output_file_path = os.path.join(output_folder, 'consolidado.xlsx')

print(f"Combining files into: {output_file_path}")

# Define the exact columns we want to keep
desired_columns = ['COORDINADORA', 'CURSO', 'NOTA', 'NOTA TXT', 'PERIODO', 'HORAS', 'CIUDAD']
print(f"Filtering for columns: {desired_columns}")

all_data = []
# Ensure we don't try to read the output file itself if it already exists in the folder (though it's in a subfolder)
files = [f for f in os.listdir(base_path) if f.endswith('.xlsx')]

for filename in files:
    file_path = os.path.join(base_path, filename)
    try:
        # Read the file
        df = pd.read_excel(file_path)
        
        # Select only the desired columns if they exist in the dataframe
        # This filters out any extra 'Unnamed' or 'Columna1' columns
        current_valid_cols = [c for c in desired_columns if c in df.columns]
        
        if current_valid_cols:
            df_subset = df[current_valid_cols]
            all_data.append(df_subset)
        else:
            print(f"Warning: {filename} contains none of the target columns.")
            
    except Exception as e:
        print(f"Error reading {filename}: {e}")

if all_data:
    # Concatenate all dataframes
    combined_df = pd.concat(all_data, ignore_index=True)
    
    # Save to Excel
    combined_df.to_excel(output_file_path, index=False)
    
    print("Success!")
    print(f"Total rows: {combined_df.shape[0]}")
    print(f"Total columns: {combined_df.shape[1]}")
    display(combined_df.head())
    print("Final columns:", combined_df.columns.tolist())
else:
    print("No data found to combine.")
# Out:
# Combining files into: lista_certificados/anion_data/consolidado.xlsx
# Success!
# Total rows: 6896
# Total columns: 11
#   COORDINADORA                                        CURSO  NOTA    NOTA TXT  \
# 0        FELIX         DISEÑO DE PÁGINAS WEB - NIVEL BÁSICO  17.0  DIECISIETE
# 1         ROSA      DISEÑO DIGITAL CON CANVA - NIVEL BÁSICO  19.0  DIECINUEVE
# 2        LUCIA  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO  15.0      QUINCE
# 3        LUCIA  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO  19.0  DIECINUEVE
# 4        LUCIA  DISEÑO DIGITAL CON CANVA - NIVEL INTERMEDIO  19.0  DIECINUEVE
#
#                                   PERIODO      HORAS CIUDAD  Columna1  \
# 0   31 - mayo - 2022 al 11 - junio - 2022  120 horas   LIMA       NaN
# 1   23 - mayo - 2022 al 03 - junio - 2022  120 horas    ICA       NaN
# 2  07 - junio - 2022 al 18 - junio - 2022  120 horas   LIMA       NaN
# 3  07 - junio - 2022 al 18 - junio - 2022  120 horas   LIMA       NaN
# 4  07 - junio - 2022 al 18 - junio - 2022  120 horas   LIMA       NaN
#
#    Unnamed: 12 Unnamed: 13  Columna2
# 0          NaN         NaN       NaN
# 1          NaN         NaN       NaN
# 2          NaN         NaN       NaN
# 3          NaN         NaN       NaN
# 4          NaN         NaN       NaN

# %%
# Verification tail data aniono
combined_df.tail()
